# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tqdm import tqdm

# %%
train = pd.read_csv("../../../data/real_or_not_nlp/train.csv")
train.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
import re
from string import punctuation
from nltk.corpus import stopwords

from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer

english_stopwords = stopwords.words('english')
stemmer = PorterStemmer()

def transform_tweet(text):
    text = re.sub("#", "", text)
    text = re.sub("\@[a-zA-Z_-]+", "", text)
    text = re.sub("^\s+", "", text)
    text = re.sub("\s+$", "", text)
    text = re.sub(f'[{punctuation}]', "", text)
    
    tokenizer = TweetTokenizer()
    words = tokenizer.tokenize(text)
    words = [word for word in words if word not in english_stopwords]
    words = [stemmer.stem(word) for word in words]
    
    return words

# %%
transformed_train = [transform_tweet(text) for text in tqdm(train.text)]
# Out:
# 100%|██████████| 7613/7613 [00:02<00:00, 2773.81it/s]

# %%
transformed_train[0]
# Out:
# ['our', 'deed', 'reason', 'earthquak', 'may', 'allah', 'forgiv', 'us']

# %%
vocab = {}
for train_sentence in transformed_train:
    for word in train_sentence:
        if word not in vocab:
            vocab[word] = len(vocab)

# %%
vocab
# Out:
# {'our': 0,
#  'deed': 1,
#  'reason': 2,
#  'earthquak': 3,
#  'may': 4,
#  'allah': 5,
#  'forgiv': 6,
#  'us': 7,
#  'forest': 8,
#  'fire': 9,
#  'near': 10,
#  'La': 11,
#  'rong': 12,
#  'sask': 13,
#  'canada': 14,
#  'all': 15,
#  'resid': 16,
#  'ask': 17,
#  'shelter': 18,
#  'place': 19,
#  'notifi': 20,
#  'offic': 21,
#  'No': 22,
#  'evacu': 23,
#  'order': 24,
#  'expect': 25,
#  '13000': 26,
#  'peopl': 27,
#  'receiv': 28,
#  'wildfir': 29,
#  'california': 30,
#  'just': 31,
#  'got': 32,
#  'sent': 33,
#  'photo': 34,
#  'rubi': 35,
#  'alaska': 36,
#  'smoke': 37,
#  'pour': 38,
#  'school': 39,
#  'rockyfir': 40,
#  'updat': 41,
#  'hwi': 42,
#  '20': 43,
#  'close': 44,
#  'direct': 45,
#  'due': 46,
#  'lake': 47,
#  'counti': 48,
#  'cafir': 49,
#  'flood': 50,
#  'disast': 51,
#  'heavi': 52,
#  'rain': 53,
#  'caus': 54,
#  'flash': 55,
#  'street': 56,
#  'manit': 57,
#  'colorado': 58,
#  'spring': 59,
#  'area': 60,
#  'Im': 61,
#  'top': 62,
#  'hill': 63,
#  'I': 64,
#  'see': 65,
#  'wood': 66,
#  'there': 67,
#  'emerg': 68,
#  'happen': 69,
#  'build': 70,
#  'across': 71,
#  'afraid': 72,
#  'tornado': 73,
#  'come': 74,
#  'three': 75,
#  'die': 76,
#  'heat': 77,
#  'wave': 78,
#  'far': 79,
#  'haha': 80,
#  'south': 81,
#  'tampa': 82,
#  'get': 83,
#  'hah': 84,
#  'wait': 85,
#  'A': 86,
#  'second': 87,
#  'live': 88,
#  'IN': 89,
#  'what': 90,
#  'AM': 91,
#  'gonna': 92,
#  'DO': 93,
#  'fvck': 94,
#  'florida': 95,
#  'tampabay': 96,
#  '18': 97,
#  '19': 98,
#  'day': 99,
#  'ive': 100,
#  'lost': 101,
#  'count': 102,
#  'bago': 103,
#  'myanmar': 104,
#  'We': 105,
#  'arriv': 106,
#  'damag': 107,
#  'bu': 108,
#  '80': 109,
#  'multi': 110,
#  'car': 111,
#  'crash': 112,
#  'break': 113,
#  'man': 114,
#  'love': 115,
#  'fruit': 116,
#  'summer': 117,
#  'My': 118,
#  'fast': 119,
#  'goooooooaaaaaal': 120,
#  'ridicul': 121,
#  'london': 122,
#  'cool': 123,
#  'ski': 124,
#  'wonder': 125,
#  'looooool': 126,
#  'wayi': 127,
#  'cant': 128,
#  'eat': 129,
#  'shit': 130,
#  'wa': 131,
#  'nyc': 132,
#  'last': 133,
#  'week': 134,
#  'girlfriend': 135,
#  'cooool': 136,
#  'Do': 137,
#  'like': 138,
#  'pasta': 139,
#  'the': 140,
#  'end': 141,
#  'wholesal': 142,
#  'market': 143,
#  'ablaz': 144,
#  'httptcolhyxeohi': 145,
#  '6C': 146,
#  'alway': 147,
#  'tri': 148,
#  'bring': 149,
#  'metal': 150,
#  'RT': 151,
#  'httptcoyao': 152,
#  '1e0xngw': 153,
#  'africanbaz': 154,
#  'newsnigeria': 155,
#  'flag': 156,
#  'set': 157,
#  'aba': 158,
#  'httptco': 159,
#  '2nndbgwyei': 160,
#  'cri': 161,
#  'On': 162,
#  'plu': 163,
#  'side': 164,
#  'look': 165,
#  'AT': 166,
#  'night': 167,
#  'IT': 168,
#  'httptcoqqsmshaj': 169,
#  '3N': 170,
#  'mufc': 171,
#  'theyv': 172,
#  'built': 173,
#  'much': 174,
#  'hype': 175,
#  'around': 176,
#  'new': 177,
#  'acquisit': 178,
#  'doubt': 179,
#  'epl': 180,
#  'season': 181,
#  'inec': 182,
#  'abia': 183,
#  '3imaomknna': 184,
#  'barbado': 185,
#  'bridgetown': 186,
#  'jamaica': 187,
#  '\x89': 188,
#  'ÛÒ': 189,
#  'two': 190,
#  'santa': 191,
#  'cruz': 192,
#  'ÛÓ': 193,
#  'head': 194,
#  'St': 195,
#  'elizabeth': 196,
#  'polic': 197,
#  'superintend': 198,
#  'httptcowdueaj': 199,
#  '8q4j': 200,
#  'lord': 201,
#  'D': 202,
#  'check': 203,
#  'httptcoroi': 204,
#  '2nsmejj': 205,
#  '3tj8zjin21': 206,
#  'httptcoyduixefip': 207,
#  'httptcolxtjc': 208,
#  '87kl': 209,
#  'nsfw': 210,
#  'outsid': 211,
#  'your': 212,
#  'aliv': 213,
#  'dead': 214,
#  'insid': 215,
#  'had': 216,
#  'awesom': 217,
#  'time': 218,
#  'visit': 219,
#  'cfc': 220,
#  'ancop': 221,
#  'site': 222,
#  'thank': 223,
#  'tita': 224,
#  'vida': 225,
#  'take': 226,
#  'care': 227,
#  'soooo': 228,
#  'pump': 229,
#  'for': 230,
#  'want': 231,
#  'chicago': 232,
#  'preach': 233,
#  'but': 234,
#  'hotel': 235,
#  'httptcoo': 236,
#  '9qknbfofx': 237,
#  'gain': 238,
#  '3': 239,
#  'follow': 240,
#  'you': 241,
#  'know': 242,
#  'stat': 243,
#  'grow': 244,
#  'httptcotiyulif': 245,
#  '5c6': 246,
#  'how': 247,
#  'west': 248,
#  'burn': 249,
#  'thousand': 250,
#  'alon': 251,
#  'httptcovl': 252,
#  '5tbr3wbr': 253,
#  'perfect': 254,
#  'tracklist': 255,
#  'life': 256,
#  'leav': 257,
#  'first': 258,
#  'retain': 259,
#  'it': 260,
#  'quit': 261,
#  'weird': 262,
#  'better': 263,
#  'use': 264,
#  'wear': 265,
#  'everi': 266,
#  'singl': 267,
#  'next': 268,
#  'year': 269,
#  'least': 270,
#  'deputi': 271,
#  'shot': 272,
#  'brighton': 273,
#  'home': 274,
#  'httptcogwnrhmso': 275,
#  '8k': 276,
#  'wife': 277,
#  'six': 278,
#  'jail': 279,
#  'niec': 280,
#  'httptcoev': 281,
#  '1ahoucza': 282,
#  'lanford': 283,
#  'salmon': 284,
#  'r': 285,
#  'httptcovplr': 286,
#  '5hka2u': 287,
#  'httptcosxhw': 288,
#  '2tnnlf': 289,
#  'arsonist': 290,
#  'deliber': 291,
#  'black': 292,
#  'church': 293,
#  'In': 294,
#  'north': 295,
#  'carolinaåêablaz': 296,
#  'httptcopcxarbh': 297,
#  '9an': 298,
#  'noch': 299,
#  'elbestia': 300,
#  'happi': 301,
#  'teammat': 302,
#  'train': 303,
#  'hard': 304,
#  'goodnight': 305,
#  'gunner': 306,
#  'httptcouc': 307,
#  '4j4jhvgr': 308,
#  'kurd': 309,
#  'trampl': 310,
#  'turkmen': 311,
#  'later': 312,
#  'other': 313,
#  'vandal': 314,
#  'front': 315,
#  'diyala': 316,
#  '4izfdyc3cg': 317,
#  'truck': 318,
#  'r21': 319,
#  'voortrekk': 320,
#  'ave': 321,
#  'OR': 322,
#  'tambo': 323,
#  'intl': 324,
#  'cargo': 325,
#  'section': 326,
#  '8kscqkfkkf': 327,
#  'heart': 328,
#  'citi': 329,
#  'gift': 330,
#  'and': 331,
#  'skylin': 332,
#  'kiss': 333,
#  'upon': 334,
#  'lip': 335,
#  'Û': 336,
#  'httpstcocyompz': 337,
#  '1a0z': 338,
#  'they': 339,
#  'sky': 340,
#  'tonight': 341,
#  'lo': 342,
#  'angel': 343,
#  'IG': 344,
#  'FB': 345,
#  'fill': 346,
#  'sunset': 347,
#  'peep': 348,
#  'httptcoicsjgz': 349,
#  '9te1': 350,
#  'climat': 351,
#  'energi': 352,
#  '9fxmn0l0bd': 353,
#  'revel': 354,
#  'wmv': 355,
#  'video': 356,
#  'mean': 357,
#  'mac': 358,
#  'farewel': 359,
#  'en': 360,
#  'rout': 361,
#  'dvd': 362,
#  'gtxrwm': 363,
#  'progress': 364,
#  'greet': 365,
#  'month': 366,
#  'student': 367,
#  'would': 368,
#  'pen': 369,
#  'torch': 370,
#  'public': 371,
#  '9fxpixqujt': 372,
#  'rene': 373,
#  'amp': 374,
#  'jacinta': 375,
#  'secret': 376,
#  '2k13': 377,
#  'fallen': 378,
#  'edit': 379,
#  'mar': 380,
#  '30': 381,
#  '2013': 382,
#  'httpstco': 383,
#  '7mlmsuzv1z': 384,
#  '7': 385,
#  'steve': 386,
#  'someth': 387,
#  'els': 388,
#  'tinderbox': 389,
#  'clown': 390,
#  'hood': 391,
#  '24680': 392,
#  'nowplay': 393,
#  'ian': 394,
#  'buff': 395,
#  'magnitud': 396,
#  'httptcoav': 397,
#  '2jsjfftc': 398,
#  'edm': 399,
#  'huge': 400,
#  'httptcorwzbfvnxer': 401,
#  'talk': 402,
#  'go': 403,
#  'dont': 404,
#  'make': 405,
#  'work': 406,
#  'kid': 407,
#  'cuz': 408,
#  'bicycl': 409,
#  'accid': 410,
#  'split': 411,
#  'testicl': 412,
#  'imposs': 413,
#  'michael': 414,
#  'are': 415,
#  'father': 416,
#  'i24': 417,
#  'W': 418,
#  'nashvilletraff': 419,
#  'traffic': 420,
#  'move': 421,
#  '8m': 422,
#  'slower': 423,
#  'usual': 424,
#  '0ghk693egj': 425,
#  'center': 426,
#  'lane': 427,
#  'block': 428,
#  'santaclara': 429,
#  'us101': 430,
#  'NB': 431,
#  'great': 432,
#  'america': 433,
#  'pkwi': 434,
#  'bayarea': 435,
#  'httptcopmlohzurwr': 436,
#  'httptcogky': 437,
#  '6gjtk5': 438,
#  'personalinjuri': 439,
#  'read': 440,
#  'advic': 441,
#  'solicitor': 442,
#  'help': 443,
#  'otleyhour': 444,
#  'stloui': 445,
#  'caraccidentlawy': 446,
#  'speed': 447,
#  'among': 448,
#  'teen': 449,
#  'httpstcok': 450,
#  '4zomof319': 451,
#  '2kxvm0cba': 452,
#  'tee': 453,
#  'report': 454,
#  'motor': 455,
#  'vehicl': 456,
#  'curri': 457,
#  'herman': 458,
#  'Rd': 459,
#  'stephenson': 460,
#  'involv': 461,
#  'overturn': 462,
#  'pleas': 463,
#  'httptcoybjezkurw': 464,
#  '1': 465,
#  'bigrigradio': 466,
#  'awar': 467,
#  'i77': 468,
#  'mile': 469,
#  'marker': 470,
#  '31': 471,
#  'mooresvil': 472,
#  'iredel': 473,
#  'ramp': 474,
#  '86': 475,
#  '118': 476,
#  'PM': 477,
#  'sleep': 478,
#  'pill': 479,
#  'doubl': 480,
#  'risk': 481,
#  '7s9nm1fict': 482,
#  'By': 483,
#  'knew': 484,
#  'gon': 485,
#  'httpstcoysxun': 486,
#  '5vceh': 487,
#  'N': 488,
#  'cabrillo': 489,
#  'hwymagellan': 490,
#  'AV': 491,
#  'mir': 492,
#  '080615 1103': 493,
#  '58': 494,
#  '40': 495,
#  'congest': 496,
#  'pastor': 497,
#  'scene': 498,
#  'accidentwho': 499,
#  'owner': 500,
#  'rang': 501,
#  'rover': 502,
#  'mom': 503,
#  'didnt': 504,
#  'wish': 505,
#  'spilt': 506,
#  'mayonnais': 507,
#  'horribl': 508,
#  'past': 509,
#  'sunday': 510,
#  'final': 511,
#  'abl': 512,
#  'god': 513,
#  'can': 514,
#  'piss': 515,
#  'donni': 516,
#  'tell': 517,
#  'anoth': 518,
#  'truckcrash': 519,
#  'fortworth': 520,
#  'interst': 521,
#  'httptcor': 522,
#  '22lj4qfp': 523,
#  'click': 524,
#  'youv': 525,
#  'crashgthttptcold': 526,
#  '0uniyw4k': 527,
#  'ashvil': 528,
#  'US': 529,
#  '23': 530,
#  'SB': 531,
#  'SR': 532,
#  '752': 533,
#  'httptcohylmo': 534,
#  '0wgfi': 535,
#  'carolina': 536,
#  'motorcyclist': 537,
#  'i540': 538,
#  'with': 539,
#  'that': 540,
#  'cross': 541,
#  'median': 542,
#  'motorcycl': 543,
#  'rider': 544,
#  'travel': 545,
#  'httptcop': 546,
#  '18lzrlmy6': 547,
#  'fyi': 548,
#  'cadfyi': 549,
#  'properti': 550,
#  'damagenh': 551,
#  '999': 552,
#  'piner': 553,
#  'rdhorndal': 554,
#  'DR': 555,
#  'naayf': 556,
#  'turn': 557,
#  'onto': 558,
#  'chandane': 559,
#  'magu': 560,
#  'mma': 561,
#  'taxi': 562,
#  'ram': 563,
#  'halfway': 564,
#  'everyon': 565,
#  'conf': 566,
#  'left': 567,
#  'manchest': 568,
#  'Rt': 569,
#  '293': 570,
#  'eddi': 571,
#  'stop': 572,
#  'back': 573,
#  'nh3a': 574,
#  'delay': 575,
#  '4': 576,
#  'min': 577,
#  'httptcooia': 578,
#  '5fxi4gm': 579,
#  'damagewpd': 580,
#  '1600': 581,
#  'S': 582,
#  '17th': 583,
#  'ST': 584,
#  '8620152': 585,
#  '09': 586,
#  'NO': 587,
#  'injuri': 588,
#  '2781': 589,
#  'willi': 590,
#  'foreman': 591,
#  'RD': 592,
#  'httptcovckit': 593,
#  '6edev': 594,
#  'aashiqui': 595,
#  'actress': 596,
#  'anu': 597,
#  'aggarw': 598,
#  'her': 599,
#  'nearfat': 600,
#  '6otfp31lqw': 601,
#  'suffield': 602,
#  'alberta': 603,
#  'httpstcobptmlf': 604,
#  '4p10': 605,
#  '9': 606,
#  'backup': 607,
#  'southaccid': 608,
#  'right': 609,
#  '2': 610,
#  'exit': 611,
#  'langtre': 612,
#  'rdconsid': 613,
#  'NC': 614,
#  '115': 615,
#  '150': 616,
#  '16': 617,
#  'altern': 618,
#  'ha': 619,
#  'chang': 620,
#  'determin': 621,
#  'option': 622,
#  'financi': 623,
#  'support': 624,
#  'plan': 625,
#  'ongo': 626,
#  'treatment': 627,
#  'deadli': 628,
#  'hagerstown': 629,
#  'today': 630,
#  'ill': 631,
#  'detail': 632,
#  '5': 633,
#  '4state': 634,
#  'whag': 635,
#  'marinad': 636,
#  'even': 637,
#  'fuck': 638,
#  'mf': 639,
#  'drive': 640,
#  'bahrain': 641,
#  'previous': 642,
#  'road': 643,
#  'kill': 644,
#  'explos': 645,
#  'httpstcogfjfgtodad': 646,
#  'still': 647,
#  'heard': 648,
#  'leader': 649,
#  'kenya': 650,
#  'forward': 651,
#  'comment': 652,
#  'issu': 653,
#  'disciplinari': 654,
#  'measuresarrestpastornganga': 655,
#  'scuf': 656,
#  'ps': 657,
#  'game': 658,
#  'cya': 659,
#  'effort': 660,
#  'pain': 661,
#  'win': 662,
#  'roger': 663,
#  'bannist': 664,
#  '320': 665,
#  'IR': 666,
#  'icemoon': 667,
#  'aftershock': 668,
#  'httptcoynxnvvkcda': 669,
#  'dubstep': 670,
#  'trapmus': 671,
#  'dnb': 672,
#  'danc': 673,
#  'ice': 674,
#  'httptcoweqpesenku': 675,
#  'victori': 676,
#  'bargain': 677,
#  'basement': 678,
#  'price': 679,
#  'dwight': 680,
#  'david': 681,
#  'eisenhow': 682,
#  'httptcovam': 683,
#  '5podgyw': 684,
#  'httptcozevakjapcz': 685,
#  'nobodi': 686,
#  'rememb': 687,
#  'came': 688,
#  'charl': 689,
#  'schulz': 690,
#  'im': 691,
#  'speak': 692,
#  'someon': 693,
#  'xb1': 694,
#  'also': 695,
#  'harder': 696,
#  'conflict': 697,
#  'gloriou': 698,
#  'triumph': 699,
#  'thoma': 700,
#  'growingupspoil': 701,
#  'clay': 702,
#  'pigeon': 703,
#  'shoot': 704,
#  'So': 705,
#  'guess': 706,
#  'one': 707,
#  'actual': 708,
#  'free': 709,
#  'TC': 710,
#  'terrifi': 711,
#  'best': 712,
#  'roller': 713,
#  'coaster': 714,
#  'ever': 715,
#  'disclaim': 716,
#  'httpstcoxmwodfmtui': 717,
#  'httptcom': 718,
#  '4jdzmgjow': 719,
#  'httptcon': 720,
#  '0uhasfkbv': 721,
#  'httptcoe': 722,
#  '14epzhoth': 723,
#  '22a9d5do6q': 724,
#  'httptcothyzomvwu': 725,
#  '0': 726,
#  '83joo0xk29': 727,
#  'wisdomw': 728,
#  'bonu': 729,
#  'minut': 730,
#  'daili': 731,
#  'habit': 732,
#  'could': 733,
#  'realli': 734,
#  'improv': 735,
#  'mani': 736,
#  'alreadi': 737,
#  'lifehack': 738,
#  'httptcotbm': 739,
#  '9fqb8cw': 740,
#  'protect': 741,
#  'yourself': 742,
#  'profit': 743,
#  'global': 744,
#  'meltdown': 745,
#  'wiedem': 746,
#  'http': 747,
#  'httptcowztz': 748,
#  '4hgmvq': 749,
#  'moment': 750,
#  'scari': 751,
#  'guy': 752,
#  'behind': 753,
#  'scream': 754,
#  'bloodi': 755,
#  'murder': 756,
#  'silverwood': 757,
#  'ã': 758,
#  '¢': 759,
#  '2010': 760,
#  'full': 761,
#  'stream': 762,
#  'youtub': 763,
#  'httptcovv': 764,
#  '3usesgf': 765,
#  'gtgt': 766,
#  '15': 767,
#  'book': 768,
#  'httptcof': 769,
#  '6ntuc734z': 770,
#  'sometim': 771,
#  'face': 772,
#  'difficulti': 773,
#  'wrong': 774,
#  'joel': 775,
#  'osteen': 776,
#  'thing': 777,
#  'stand': 778,
#  'dream': 779,
#  'belief': 780,
#  'possibl': 781,
#  'brown': 782,
#  'prais': 783,
#  'ministri': 784,
#  'wdyouth': 785,
#  'biblestudi': 786,
#  'httpstcoujk': 787,
#  '0e5gbcc': 788,
#  'way': 789,
#  'avoid': 790,
#  'trap': 791,
#  'think': 792,
#  'lose': 793,
#  'job': 794,
#  'orang': 795,
#  'never': 796,
#  'bb': 797,
#  'httpstcojv': 798,
#  '8p': 799,
#  'pkhji': 800,
#  'kick': 801,
#  'say': 802,
#  'cannot': 803,
#  'done': 804,
#  'interrupt': 805,
#  'georg': 806,
#  'bernard': 807,
#  'shaw': 808,
#  'oyster': 809,
#  'shell': 810,
#  'andrew': 811,
#  'carnegi': 812,
#  'anyon': 813,
#  'need': 814,
#  'PU': 815,
#  'play': 816,
#  'hybrid': 817,
#  'slayer': 818,
#  'ps4': 819,
#  'EU': 820,
#  'hmu': 821,
#  '8sandscrim': 822,
#  '4tpkotc': 823,
#  '4tpfa': 824,
#  'expert': 825,
#  'franc': 826,
#  'begin': 827,
#  'examin': 828,
#  'airplan': 829,
#  'debri': 830,
#  'found': 831,
#  'reunion': 832,
#  'island': 833,
#  'french': 834,
#  'air': 835,
#  'httptcoyvvpznzmxg': 836,
#  'news': 837,
#  'strict': 838,
#  'liabil': 839,
#  'context': 840,
#  'pilot': 841,
#  'error': 842,
#  'common': 843,
#  'compon': 844,
#  'aviat': 845,
#  'cr': 846,
#  '6cz3bohrd4': 847,
#  'lifetim': 848,
#  'odd': 849,
#  '8015': 850,
#  'wedn': 851,
#  'httptcobkpfpogysi': 852,
#  'awwww': 853,
#  'theyr': 854,
#  'cuti': 855,
#  'good': 856,
#  'famili': 857,
#  'member': 858,
#  'osama': 859,
#  'bin': 860,
#  'laden': 861,
#  'iron': 862,
#  'mhmmm': 863,
#  'gov': 864,
#  'suspect': 865,
#  'goe': 866,
#  'engin': 867,
#  'httptcotyjxrfd': 868,
#  '3st': 869,
#  'via': 870,
#  'wing': 871,
#  '2907201': 872,
#  'httptcoi': 873,
#  '7kztevb2v': 874,
#  'cessna': 875,
#  'ocampo': 876,
#  'coahuila': 877,
#  'mexico': 878,
#  'juli': 879,
#  '29': 880,
#  '2015': 881,
#  'four': 882,
#  'men': 883,
#  'includ': 884,
#  'state': 885,
#  'govern': 886,
#  'offici': 887,
#  'watchthevideo': 888,
#  '64xrvgjik': 889,
#  'httptcolsmx': 890,
#  '2vwr3j': 891,
#  'wednesday': 892,
#  'began': 893,
#  'kca': 894,
#  'votejkt': 895,
#  '48id': 896,
#  'mbataweel': 897,
#  'rip': 898,
#  'binladen': 899,
#  'almost': 900,
#  'cowork': 901,
#  'nude': 902,
#  'mode': 903,
#  'might': 904,
#  'wreck': 905,
#  'polit': 906,
#  'httptcotagzbcxfj': 907,
#  'mlb': 908,
#  'thi': 909,
#  'unbeliev': 910,
#  'insan': 911,
#  'airport': 912,
#  'aircraft': 913,
#  'aeroplan': 914,
#  'runway': 915,
#  'freaki': 916,
#  'httpstcocezhq': 917,
#  '7czll': 918,
#  'airplaneåê': 919,
#  'httptcowq': 920,
#  '3wjsgphl': 921,
#  'httptcotfcdronra': 922,
#  '6': 923,
#  'usama': 924,
#  'ladin': 925,
#  'natur': 926,
#  'plane': 927,
#  'At': 928,
#  'festiv': 929,
#  'httpstcokq': 930,
#  '9ae6ap2b': 931,
#  'death': 932,
#  'carfest': 933,
#  'httptcogibyqhhkpk': 934,
#  'dtn': 935,
#  'brazil': 936,
#  'exp': 937,
#  '9ig3wq8lq': 938,
#  'httptcov': 939,
#  '4smaeslk5': 940,
#  'Of': 941,
#  'ûïairplan': 942,
#  '\x9d': 943,
#  'wtf': 944,
#  'ûªt': 945,
#  'believ': 946,
#  'eye': 947,
#  '6ffylajwp': 948,
#  'nicol': 949,
#  'fletcher': 950,
#  'victim': 951,
#  'ago': 952,
#  'littl': 953,
#  'bit': 954,
#  'trauma': 955,
#  'although': 956,
#  'she': 957,
#  'omg': 958,
#  'httptcoxdxdprcpn': 959,
#  'bro': 960,
#  'jetengin': 961,
#  'turbojet': 962,
#  'bo': 963,
#  'g90': 964,
#  'httptcokxxnszp': 965,
#  '6nk': 966,
#  'phone': 967,
#  'ship': 968,
#  'terribl': 969,
#  'statist': 970,
#  'cop': 971,
#  'hous': 972,
#  'colombia': 973,
#  '12': 974,
#  'httpstcozhjlflbhzl': 975,
#  'httpstcoiecc': 976,
#  '1jdoub': 977,
#  'drone': 978,
#  'worri': 979,
#  'esp': 980,
#  'vicin': 981,
#  'httptcokz': 982,
#  '35rgngjf': 983,
#  'earli': 984,
#  'wake': 985,
#  'call': 986,
#  'sister': 987,
#  'beg': 988,
#  'ride': 989,
#  'wher': 990,
#  'ambul': 991,
#  'hospit': 992,
#  'rodkiai': 993,
#  'httptcoay': 994,
#  '6zzcupnz': 995,
#  'twelv': 996,
#  'fear': 997,
#  'pakistani': 998,
#  'helicopt': 999,
#  ...}

# %%
len(vocab)
# Out:
# 19589

# %%
vocab_size = len(vocab)
embeddings_size = 256
bs = 64

model = tf.keras.Sequential(
    [
        tf.keras.layers.Input(shape=(vocab_size,)),
        tf.keras.layers.Embedding(embeddings_size, bs),
        tf.keras.layers.Dense(1, activation='softmax'),
    ]
)

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 19589, 64)         16384
# _________________________________________________________________
# dense_3 (Dense)              (None, 19589, 1)          65
# =================================================================
# Total params: 16,449
# Trainable params: 16,449
# Non-trainable params: 0
# _________________________________________________________________

# %%
def vectorize_tweet(transformed_tweet):
    vector = np.zeros(vocab_size)
    
    for word in transformed_tweet:
        if word in vocab:
            vector[vocab.get(word)] = 1.
            
    return vector / sum(vector)

# %%
vectorized_train = [vectorize_tweet(tweet) for tweet in tqdm(transformed_train)]
# Out:
# 100%|██████████| 7613/7613 [00:24<00:00, 317.06it/s]

# %%
model(vectorized_train[0])
# Out:
# <tf.Tensor: shape=(19589, 1), dtype=float32, numpy=
# array([[1.],
#        [1.],
#        [1.],
#        ...,
#        [1.],
#        [1.],
#        [1.]], dtype=float32)>

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.binary_crossentropy, metrics=['acc'])

# %%
X = np.array(vectorized_train)
y = train.target.values.astype(np.float)

# %%
model.fit(x=X, y=y, batch_size=64, epochs=5)
# Out:
# Epoch 1/5
# 119/119 [==============================] - 30s 252ms/step - loss: 8.6973 - acc: 0.4297
# Epoch 2/5
# 119/119 [==============================] - 30s 251ms/step - loss: 8.6973 - acc: 0.4297
# Epoch 3/5
# 119/119 [==============================] - 32s 271ms/step - loss: 8.6973 - acc: 0.4297
# Epoch 4/5
# 119/119 [==============================] - 30s 254ms/step - loss: 8.6973 - acc: 0.4297
# Epoch 5/5
# 119/119 [==============================] - 31s 260ms/step - loss: 8.6973 - acc: 0.4297

# %%
test = pd.read_csv("../../../data/real_or_not_nlp/test.csv")
test.head()
# Out:
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %%
transformed_test = [transform_tweet(text) for text in tqdm(test.text)]
vectorized_ttes = [vectorize_tweet(tweet) for tweet in tqdm(transformed_test)]
# Out:
# 100%|██████████| 3263/3263 [00:01<00:00, 2811.57it/s]
#  22%|██▏       | 731/3263 [00:02<00:07, 343.80it/s]/Users/robikos/anaconda3/envs/nlp/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in true_divide
#
# 100%|██████████| 3263/3263 [00:10<00:00, 321.81it/s]

# %%
res = model.predict(x=vectorized_ttes, batch_size=64)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 19589) for input Tensor("input_4:0", shape=(None, 19589), dtype=float32), but it was called on an input with incompatible shape (None, 1).

# %%
res = res.reshape(19589,)

# %%
pd.Series(res).value_counts()
# Out:
# 1.0    19589
# dtype: int64

# %%
test.shape
# Out:
# (3263, 4)

# %%
res.shape
# Out:
# (19589,)
